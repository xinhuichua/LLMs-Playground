# %%
# !pip install --upgrade scipy numpy gensim
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.13.1)
# Collecting scipy
#   Using cached scipy-1.16.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.3.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.3.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)

# %%
from gensim.models import Word2Vec

import gensim.downloader as api
from gensim.utils import simple_preprocess
import gensim.models

# %%
wv = api.load('20-newsgroups') # for a smaller dataset faster to download you may use instead: 'semeval-2016-2017-task3-subtaskBC'
# download the corpus and return it opened as an iterable
# other datasets available at - https://github.com/piskvorky/gensim-data

# Extract text data from the 'data' field and preprocess
processed_text = [simple_preprocess(doc['data']) for doc in wv]

model = Word2Vec(processed_text, min_count=3) # train a model from the corpus
# Out:
# [==================================================] 100.1% 13.8/13.8MB downloaded

# %%
vocab = list(model.wv.key_to_index.keys())
print(vocab)
print("Vocab len is", len(vocab))
# Out:
# ['the', 'to', 'of', 'and', 'in', 'is', 'that', 'ax', 'it', 'for', 'you', 'from', 'edu', 'on', 'this', 'be', 'not', 'are', 'have', 'with', 'as', 'or', 'was', 'if', 'but', 'they', 'com', 'subject', 'lines', 'can', 'organization', 'at', 'by', 're', 'an', 'what', 'my', 'there', 'all', 'would', 'we', 'one', 'will', 'do', 'he', 'about', 'writes', 'so', 'no', 'your', 'article', 'has', 'any', 'me', 'who', 'some', 'out', 'which', 'don', 'more', 'like', 'people', 'university', 'when', 'just', 'were', 'posting', 'their', 'up', 'know', 'how', 'other', 'host', 'get', 'only', 'them', 'nntp', 'had', 'than', 'been', 'think', 'his', 'also', 'does', 'time', 'use', 'then', 'new', 'apr', 'these', 'good', 'should', 'could', 'may', 'ca', 'well', 'am', 'us', 'because', 'now', 'even', 'why', 'see', 'very', 'into', 'cs', 'god', 'way', 'two', 'those', 'max', 'first', 'make', 'much', 'many', 'system', 've', 'most', 'world', 'distribution', 'say', 'right', 'such', 'here', 'where', 'did', 'our', 'anyone', 'want', 'go', 'after', 'used', 'its', 'over', 'reply', 'being', 'said', 'same', 'need', 'work', 'state', 'too', 'really', 'please', 'problem', 'something', 'computer', 'windows', 'him', 'since', 'believe', 'back', 'off', 'mail', 'still', 'going', 'help', 'file', 'information', 'find', 'before', 'year', 'll', 'take', 'point', 'using', 'government', 'last', 'question', 'might', 'years', 'never', 'news', 'thanks', 'software', 'while', 'things', 'better', 'read', 'both', 'usa', 'must', 'bit', 'david', 'own', 'etc', 'space', 'number', 'sure', 'without', 'another', 'uk', 'made', 'someone', 'data', 'case', 'drive', 'through', 'down', 'doesn', 'program', 'let', 'long', 'got', 'between', 'part', 'under', 'thing', 'version', 'look', 'available', 'day', 'few', 'power', 'come', 'around', 'little', 'each', 'fact', 'anything', 'however', 'ac', 'didn', 'law', 'key', 'cc', 'sun', 'john', 'against', 'again', 'give', 'best', 'every', 'dos', 'org', 'game', 'probably', 'she', 'access', 'seems', 'public', 'car', 'group', 'different', 'true', 'gov', 'least', 'net', 'line', 'run', 'set', 'tell', 'put', 'enough', 'try', 'name', 'science', 'course', 'lot', 'actually', 'great', 'support', 'research', 'list', 'her', 'high', 'nasa', 'real', 'de', 'systems', 'life', 'says', 'post', 'hard', 'inc', 'far', 'either', 'pl', 'old', 'though', 'free', 'man', 'second', 'jesus', 'called', 'possible', 'nothing', 'mr', 'end', 'else', 'rather', 'message', 'wrong', 'card', 'mean', 'call', 'ibm', 'image', 'team', 'next', 'files', 'reason', 'yes', 'mark', 'problems', 'technology', 'hp', 'internet', 'st', 'netcom', 'email', 'keep', 'looking', 'found', 'person', 'pc', 'non', 'graphics', 'done', 'based', 'above', 'seen', 'others', 'able', 'center', 'maybe', 'yet', 'having', 'order', 'info', 'gun', 'general', 'send', 'mac', 'always', 'place', 'bill', 'three', 'isn', 'example', 'chip', 'bad', 'ever', 'thought', 'mb', 'following', 'israel', 'quite', 'control', 'doing', 'heard', 'less', 'mit', 'once', 'wrote', 'phone', 'christian', 'window', 'trying', 'book', 'several', 'left', 'uucp', 'won', 'ftp', 'home', 'michael', 'whether', 'au', 'given', 'big', 'children', 'times', 'keywords', 'means', 'idea', 'opinions', 'national', 'away', 'start', 'getting', 'today', 'co', 'kind', 'evidence', 'human', 'apple', 'word', 'american', 'questions', 'ms', 'note', 'during', 'paul', 'win', 'remember', 'scsi', 'code', 'seem', 'source', 'andrew', 'change', 'unix', 'steve', 'washington', 'standard', 'fax', 'president', 'local', 'department', 'makes', 'games', 'uiuc', 'cannot', 'disk', 'already', 'price', 'full', 'mike', 'stuff', 'large', 'ask', 'until', 'jews', 'running', 'small', 'perhaps', 'address', 'money', 'speed', 'saying', 'answer', 'type', 'play', 'came', 'sale', 'institute', 'days', 'original', 'ago', 'bible', 'current', 'buy', 'interested', 'show', 'open', 'color', 'th', 'told', 'issue', 'machine', 'pretty', 'war', 'works', 'whole', 'jim', 'rights', 'hope', 'server', 'matter', 'box', 'feel', 'hand', 'clipper', 'can ...
# Vocab len is 52656

# %%
model.wv.most_similar("cat")
# Out:
# [('seer', 0.5897456407546997),
#  ('schlumberger', 0.583827555179596),
#  ('brookbank', 0.5827762484550476),
#  ('itw', 0.5799059271812439),
#  ('birnbaum', 0.5797992944717407),
#  ('dettwiler', 0.5794937610626221),
#  ('jack', 0.5785101652145386),
#  ('mcdougall', 0.5684351325035095),
#  ('macdonald', 0.5654494762420654),
#  ('fermilab', 0.5619556307792664)]

# %%
model.wv.similarity("question", "questions")
# Out:
# 0.6326371

# %%
model.wv.most_similar(positive=['argument'], topn=5)
# Out:
# [('assertion', 0.8080422878265381),
#  ('assumption', 0.7979294061660767),
#  ('statement', 0.7908033728599548),
#  ('reasoning', 0.778425395488739),
#  ('interpretation', 0.7739891409873962)]

# %%
print(model.wv.does)
